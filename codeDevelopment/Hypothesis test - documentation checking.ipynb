# %%
# %matplotlib inline

import pandas as pd
import numpy as np

from pandas.api.types import CategoricalDtype

from collections import defaultdict, Counter

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt
import matplotlib.dates as mdates

import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.formula.api as smf

import dataStatsAnalysis as dsa

# %%
# First check that my added sampling distribution attribute is working properly
data1 = np.random.randint(17,23,size=100)
data1
# Out:
# array([21, 19, 22, 22, 19, 19, 19, 21, 17, 19, 17, 18, 22, 19, 17, 19, 21,
#        20, 18, 20, 17, 20, 22, 19, 20, 20, 19, 21, 22, 17, 18, 17, 21, 19,
#        19, 20, 20, 20, 17, 18, 17, 19, 20, 21, 18, 22, 22, 19, 18, 18, 20,
#        19, 21, 21, 19, 22, 18, 19, 18, 21, 21, 22, 21, 19, 21, 20, 20, 19,
#        19, 17, 22, 22, 20, 19, 17, 20, 22, 20, 22, 20, 18, 19, 18, 20, 21,
#        17, 18, 21, 18, 21, 19, 17, 22, 20, 21, 17, 22, 18, 18, 20])

# %%
htmean = dsa.HTMean(data1, test_stat=19.15, tail='left')

# %%
htmean.sampling_dist
# Out:
# array([19.53, 19.38, 19.66, 19.62, 19.43, 19.28, 19.49, 19.62, 19.62,
#        19.52, 19.8 , 19.73, 19.4 , 19.4 , 19.73, 19.95, 19.57, 19.42,
#        19.94, 19.47, 19.63, 19.71, 19.89, 19.6 , 19.33, 19.47, 19.66,
#        19.86, 19.49, 19.19, 19.45, 19.6 , 19.33, 19.58, 19.3 , 19.56,
#        19.53, 19.3 , 19.7 , 19.69, 19.38, 19.47, 19.38, 19.84, 19.72,
#        19.71, 19.39, 19.63, 19.67, 19.57, 19.51, 19.44, 19.41, 19.42,
#        19.57, 19.52, 19.45, 19.54, 19.64, 19.61, 19.21, 19.56, 19.46,
#        19.59, 19.52, 19.71, 19.63, 19.53, 19.52, 19.51, 19.5 , 19.31,
#        19.53, 19.78, 19.59, 19.56, 19.41, 19.42, 19.4 , 19.51, 19.75,
#        19.45, 19.6 , 19.58, 19.26, 19.61, 19.83, 19.41, 19.54, 19.6 ,
#        19.3 , 19.71, 19.67, 19.56, 19.75, 19.55, 19.8 , 19.45, 19.81,
#        19.38, 19.47, 19.35, 19.56, 19.49, 19.6 , 19.28, 19.51, 19.7 ,
#        19.67, 19.25, 19.4 , 19.78, 19.49, 19.58, 19.65, 19.45, 19.37,
# ...

# %%
htmean.rv

# %%
htmean.Power()
# Out:
# 0.794
